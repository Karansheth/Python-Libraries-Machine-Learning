# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52,48,47,49,46]

# %%
x
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
y
# Out:
# [50, 51, 52, 48, 47, 49, 46]

# %%
plt.title("Weather Prediction")
plt.xlabel("Day")
plt.ylabel("Temperature")
plt.plot(x, y, linestyle=':', color="r", linewidth="5", marker='o', markersize=15)

# %%
plt.title("Weather Prediction")
plt.xlabel("Day")
plt.ylabel("Temperature")
plt.plot(x, y, 'g+-.', alpha=0.5)#alpha is for blur
